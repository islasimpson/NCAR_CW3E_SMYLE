# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from math import nan
import sys

from smyleutils import averaging_utils as avg
from smyleutils import qboplot_utils as qbo
from smyleutils import colorbar_utils as cbars
from smyleutils import bootstrap_utils as boot
import importlib
importlib.reload(qbo)
# Out:
# <module 'smyleutils.qboplot_utils' from '/glade/u/home/islas/python/NCAR_CW3E_SMYLE/smyleutils/qboplot_utils.py'>

# %%
plotpath="/glade/campaign/cgd/cas/islas/python_plots/NCAR_CW3E_SMYLE/FIGURES/SUPP/"

# %%
basepath="/glade/campaign/cgd/cas/islas/python_savs/NCAR_CW3E_SMYLE/DATA_SORT/Tzm/"
high_nov_tzm=xr.open_dataset(basepath+'Tzm_BSMYLE-CW3E-L83_day_init11.nc').Tzm
low_nov_tzm=xr.open_dataset(basepath+'Tzm_BSMYLE-CW3E_day_init11.nc').Tzm
era5_nov_tzm=xr.open_dataset(basepath+'Tzm_ERA5_day_init11.nc').Tzm
jra3q_nov_tzm = xr.open_dataset(basepath+'Tzm_JRA3Q_day_init11.nc').Tzm

high_feb_tzm=xr.open_dataset(basepath+'Tzm_BSMYLE-CW3E-L83_day_init02.nc').Tzm
low_feb_tzm=xr.open_dataset(basepath+'Tzm_BSMYLE-CW3E_day_init02.nc').Tzm
era5_feb_tzm=xr.open_dataset(basepath+'Tzm_ERA5_day_init02.nc').Tzm
jra3q_feb_tzm = xr.open_dataset(basepath+'Tzm_JRA3Q_day_init02.nc').Tzm

high_sep_tzm=xr.open_dataset(basepath+'Tzm_BSMYLE-CW3E-L83_day_init09.nc').Tzm
low_sep_tzm=xr.open_dataset(basepath+'Tzm_BSMYLE-CW3E_day_init09.nc').Tzm
era5_sep_tzm=xr.open_dataset(basepath+'Tzm_ERA5_day_init09.nc').Tzm
jra3q_sep_tzm = xr.open_dataset(basepath+'Tzm_JRA3Q_day_init09.nc').Tzm

# %% [markdown]
# ### Get the first 6 months since that's what we have for the L83

# %%
startdate=high_nov_tzm.time.isel(time=0).values ; enddate=high_nov_tzm.time.isel(time=high_nov_tzm.time.size-1).values
high_nov_tzm = high_nov_tzm.sel(time=slice(startdate,enddate))
low_nov_tzm = low_nov_tzm.sel(time=slice(startdate,enddate))
era5_nov_tzm = era5_nov_tzm.sel(time=slice(startdate,enddate))
jra3q_nov_tzm = jra3q_nov_tzm.sel(time=slice(startdate, enddate))

startdate=high_sep_tzm.time.isel(time=0).values ; enddate=high_sep_tzm.time.isel(time=high_sep_tzm.time.size-1).values
high_sep_tzm = high_sep_tzm.sel(time=slice(startdate,enddate))
low_sep_tzm = low_sep_tzm.sel(time=slice(startdate,enddate))
era5_sep_tzm = era5_sep_tzm.sel(time=slice(startdate,enddate))
jra3q_sep_tzm = jra3q_sep_tzm.sel(time=slice(startdate, enddate))

startdate=high_feb_tzm.time.isel(time=0).values ; enddate=high_feb_tzm.time.isel(time=high_feb_tzm.time.size-1).values
high_feb_tzm = high_feb_tzm.sel(time=slice(startdate,enddate))
low_feb_tzm = low_feb_tzm.sel(time=slice(startdate,enddate))
era5_feb_tzm = era5_feb_tzm.sel(time=slice(startdate,enddate))
jra3q_feb_tzm = jra3q_feb_tzm.sel(time=slice(startdate,enddate))

# %% [markdown]
# ### Get the tropical averaged zonal mean temperature

# %%
high_nov_tzm_tr = avg.cosweightlat(high_nov_tzm,-5,5).load()
low_nov_tzm_tr = avg.cosweightlat(low_nov_tzm,-5,5).load()
era5_nov_tzm_tr = avg.cosweightlat(era5_nov_tzm,-5,5).load()
jra3q_nov_tzm_tr = avg.cosweightlat(jra3q_nov_tzm,-5,5).load()

high_sep_tzm_tr = avg.cosweightlat(high_sep_tzm,-5,5).load()
low_sep_tzm_tr = avg.cosweightlat(low_sep_tzm,-5,5).load()
era5_sep_tzm_tr = avg.cosweightlat(era5_sep_tzm,-5,5).load()
jra3q_sep_tzm_tr = avg.cosweightlat(jra3q_sep_tzm,-5,5).load()

high_feb_tzm_tr = avg.cosweightlat(high_feb_tzm,-5,5).load()
low_feb_tzm_tr = avg.cosweightlat(low_feb_tzm,-5,5).load()
era5_feb_tzm_tr = avg.cosweightlat(era5_feb_tzm,-5,5).load()
jra3q_feb_tzm_tr = avg.cosweightlat(jra3q_feb_tzm,-5,5).load()
# Out:
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat
# DataArrayWeighted with weights along dimensions: lat

# %% [markdown]
# ### Interpolate the model data from the pressure levels of the CAM TEM diagnostics onto the ERA5 pressure levels

# %%
high_nov_tzm_tr_interp = high_nov_tzm_tr.interp(ilev=era5_nov_tzm.level)
low_nov_tzm_tr_interp = low_nov_tzm_tr.interp(ilev=era5_nov_tzm.level)
jra3q_nov_tzm_tr_interp = jra3q_nov_tzm_tr.interp(pre=era5_nov_tzm.level)

high_sep_tzm_tr_interp = high_sep_tzm_tr.interp(ilev=era5_nov_tzm.level)
low_sep_tzm_tr_interp = low_sep_tzm_tr.interp(ilev=era5_nov_tzm.level)
jra3q_sep_tzm_tr_interp = jra3q_sep_tzm_tr.interp(pre=era5_nov_tzm.level)

high_feb_tzm_tr_interp = high_feb_tzm_tr.interp(ilev=era5_nov_tzm.level)
low_feb_tzm_tr_interp = low_feb_tzm_tr.interp(ilev=era5_nov_tzm.level)
jra3q_feb_tzm_tr_interp = jra3q_feb_tzm_tr.interp(pre=era5_nov_tzm.level)

# %% [markdown]
# ### Calculate the ensemble mean

# %%
high_nov_tzm_tr_interpm = high_nov_tzm_tr_interp.mean('M')
low_nov_tzm_tr_interpm = low_nov_tzm_tr_interp.mean('M')

high_sep_tzm_tr_interpm = high_sep_tzm_tr_interp.mean('M')
low_sep_tzm_tr_interpm = low_sep_tzm_tr_interp.mean('M')

high_feb_tzm_tr_interpm = high_feb_tzm_tr_interp.mean('M')
low_feb_tzm_tr_interpm = low_feb_tzm_tr_interp.mean('M')

# %% [markdown]
# ### Calculate the lead dependent climatology

# %%
era5_nov_tzm_tr_clim = era5_nov_tzm_tr.mean('init_year')
jra3q_nov_tzm_tr_interp_clim = jra3q_nov_tzm_tr_interp.mean('init_year')
high_nov_tzm_tr_interpm_clim = high_nov_tzm_tr_interpm.mean('init_year')
low_nov_tzm_tr_interpm_clim = low_nov_tzm_tr_interpm.mean('init_year')

era5_sep_tzm_tr_clim = era5_sep_tzm_tr.mean('init_year')
jra3q_sep_tzm_tr_interp_clim = jra3q_sep_tzm_tr_interp.mean('init_year')
high_sep_tzm_tr_interpm_clim = high_sep_tzm_tr_interpm.mean('init_year')
low_sep_tzm_tr_interpm_clim = low_sep_tzm_tr_interpm.mean('init_year')

era5_feb_tzm_tr_clim = era5_feb_tzm_tr.mean('init_year')
jra3q_feb_tzm_tr_interp_clim = jra3q_feb_tzm_tr_interp.mean('init_year')
high_feb_tzm_tr_interpm_clim = high_feb_tzm_tr_interpm.mean('init_year')
low_feb_tzm_tr_interpm_clim = low_feb_tzm_tr_interpm.mean('init_year')

# %% [markdown]
# ### Subtract the lead dependent climatology from ERA5 and the SMYLE ensemble mean and the SMYLE individual members

# %%
era5_nov_tzm_tr = era5_nov_tzm_tr - era5_nov_tzm_tr_clim
jra3q_nov_tzm_tr_interp = jra3q_nov_tzm_tr_interp - jra3q_nov_tzm_tr_interp_clim
high_nov_tzm_tr_interp = high_nov_tzm_tr_interp - high_nov_tzm_tr_interpm_clim
low_nov_tzm_tr_interp = low_nov_tzm_tr_interp - low_nov_tzm_tr_interpm_clim
high_nov_tzm_tr_interpm = high_nov_tzm_tr_interpm - high_nov_tzm_tr_interpm_clim
low_nov_tzm_tr_interpm = low_nov_tzm_tr_interpm - low_nov_tzm_tr_interpm_clim

era5_sep_tzm_tr = era5_sep_tzm_tr - era5_sep_tzm_tr_clim
jra3q_sep_tzm_tr_interp = jra3q_sep_tzm_tr_interp - jra3q_sep_tzm_tr_interp_clim
high_sep_tzm_tr_interp = high_sep_tzm_tr_interp - high_sep_tzm_tr_interpm_clim
low_sep_tzm_tr_interp = low_sep_tzm_tr_interp - low_sep_tzm_tr_interpm_clim
high_sep_tzm_tr_interpm = high_sep_tzm_tr_interpm - high_sep_tzm_tr_interpm_clim
low_sep_tzm_tr_interpm = low_sep_tzm_tr_interpm - low_sep_tzm_tr_interpm_clim

era5_feb_tzm_tr = era5_feb_tzm_tr - era5_feb_tzm_tr_clim
jra3q_feb_tzm_tr_interp = jra3q_feb_tzm_tr_interp - jra3q_feb_tzm_tr_interp_clim
high_feb_tzm_tr_interp = high_feb_tzm_tr_interp - high_feb_tzm_tr_interpm_clim
low_feb_tzm_tr_interp = low_feb_tzm_tr_interp - low_feb_tzm_tr_interpm_clim
high_feb_tzm_tr_interpm = high_feb_tzm_tr_interpm - high_feb_tzm_tr_interpm_clim
low_feb_tzm_tr_interpm = low_feb_tzm_tr_interpm - low_feb_tzm_tr_interpm_clim

# last 2 months
era5_nov_tzm_tr_2mon = era5_nov_tzm_tr[:,-60:,:].mean('time')
jra3q_nov_tzm_tr_2mon = jra3q_nov_tzm_tr_interp[:,-60:,:].mean('time')
high_nov_tzm_tr_2mon = high_nov_tzm_tr_interpm[:,-60:,:].mean('time')
low_nov_tzm_tr_2mon = low_nov_tzm_tr_interpm[:,-60:,:].mean('time')

era5_sep_tzm_tr_2mon = era5_sep_tzm_tr[:,-60:,:].mean('time')
jra3q_sep_tzm_tr_2mon = jra3q_sep_tzm_tr_interp[:,-60:,:].mean('time')
high_sep_tzm_tr_2mon = high_sep_tzm_tr_interpm[:,-60:,:].mean('time')
low_sep_tzm_tr_2mon = low_sep_tzm_tr_interpm[:,-60:,:].mean('time')

era5_feb_tzm_tr_2mon = era5_feb_tzm_tr[:,-60:,:].mean('time')
jra3q_feb_tzm_tr_2mon = jra3q_feb_tzm_tr_interp[:,-60:,:].mean('time')
high_feb_tzm_tr_2mon = high_feb_tzm_tr_interpm[:,-60:,:].mean('time')
low_feb_tzm_tr_2mon = low_feb_tzm_tr_interpm[:,-60:,:].mean('time')

# %% [markdown]
# ### Mean squared skill score calculation

# %%
def calcmsss(mod,obs,dim='init_year'):
    mse_mod = (1./mod[dim].size)*((mod - obs)**2).sum('init_year')
    mse_obs = (1./mod[dim].size)*(obs**2).sum('init_year')
    msss = 1 - (mse_mod / mse_obs)
    
    # dealing with the levels where low top doesn't have any data
    msss = msss.where( msss != 1, nan)
    return msss

# %%
msss_high_nov_tzm = calcmsss(high_nov_tzm_tr_interpm, era5_nov_tzm_tr)
msss_low_nov_tzm = calcmsss(low_nov_tzm_tr_interpm, era5_nov_tzm_tr)
msss_high_nov_2mon_tzm = calcmsss(high_nov_tzm_tr_2mon, era5_nov_tzm_tr_2mon)
msss_low_nov_2mon_tzm = calcmsss(low_nov_tzm_tr_2mon, era5_nov_tzm_tr_2mon)
msss_high_nov_2mon_tzm_jra = calcmsss(high_nov_tzm_tr_2mon, jra3q_nov_tzm_tr_2mon)
msss_low_nov_2mon_tzm_jra = calcmsss(low_nov_tzm_tr_2mon, jra3q_nov_tzm_tr_2mon)

msss_high_sep_tzm = calcmsss(high_sep_tzm_tr_interpm, era5_sep_tzm_tr)
msss_low_sep_tzm = calcmsss(low_sep_tzm_tr_interpm, era5_sep_tzm_tr)
msss_high_sep_2mon_tzm = calcmsss(high_sep_tzm_tr_2mon, era5_sep_tzm_tr_2mon)
msss_low_sep_2mon_tzm = calcmsss(low_sep_tzm_tr_2mon, era5_sep_tzm_tr_2mon)
msss_high_sep_2mon_tzm_jra = calcmsss(high_sep_tzm_tr_2mon, jra3q_sep_tzm_tr_2mon)
msss_low_sep_2mon_tzm_jra = calcmsss(low_sep_tzm_tr_2mon, jra3q_sep_tzm_tr_2mon)

msss_high_feb_tzm = calcmsss(high_feb_tzm_tr_interpm, era5_feb_tzm_tr)
msss_low_feb_tzm = calcmsss(low_feb_tzm_tr_interpm, era5_feb_tzm_tr)
msss_high_feb_2mon_tzm = calcmsss(high_feb_tzm_tr_2mon, era5_feb_tzm_tr_2mon)
msss_low_feb_2mon_tzm = calcmsss(low_feb_tzm_tr_2mon, era5_feb_tzm_tr_2mon)
msss_high_feb_2mon_tzm_jra = calcmsss(high_feb_tzm_tr_2mon, jra3q_feb_tzm_tr_2mon)
msss_low_feb_2mon_tzm_jra = calcmsss(low_feb_tzm_tr_2mon, jra3q_feb_tzm_tr_2mon)

# %% [markdown]
# ### Anomaly correlation coefficient

# %%
acc_high_nov_tzm = xr.corr(era5_nov_tzm_tr, high_nov_tzm_tr_interpm, dim='init_year')
acc_low_nov_tzm = xr.corr(era5_nov_tzm_tr, low_nov_tzm_tr_interpm, dim='init_year')
acc_high_nov_2mon_tzm = xr.corr(era5_nov_tzm_tr_2mon, high_nov_tzm_tr_2mon, dim='init_year')
acc_low_nov_2mon_tzm = xr.corr(era5_nov_tzm_tr_2mon, low_nov_tzm_tr_2mon, dim='init_year')
acc_high_nov_2mon_tzm_jra = xr.corr(jra3q_nov_tzm_tr_2mon, high_nov_tzm_tr_2mon, dim='init_year')
acc_low_nov_2mon_tzm_jra = xr.corr(jra3q_nov_tzm_tr_2mon, low_nov_tzm_tr_2mon, dim='init_year')

acc_high_sep_tzm = xr.corr(era5_sep_tzm_tr, high_sep_tzm_tr_interpm, dim='init_year')
acc_low_sep_tzm = xr.corr(era5_sep_tzm_tr, low_sep_tzm_tr_interpm, dim='init_year')
acc_high_sep_2mon_tzm = xr.corr(era5_sep_tzm_tr_2mon, high_sep_tzm_tr_2mon, dim='init_year')
acc_low_sep_2mon_tzm = xr.corr(era5_sep_tzm_tr_2mon, low_sep_tzm_tr_2mon, dim='init_year')
acc_high_sep_2mon_tzm_jra = xr.corr(jra3q_sep_tzm_tr_2mon, high_sep_tzm_tr_2mon, dim='init_year')
acc_low_sep_2mon_tzm_jra = xr.corr(jra3q_sep_tzm_tr_2mon, low_sep_tzm_tr_2mon, dim='init_year')

acc_high_feb_tzm = xr.corr(era5_feb_tzm_tr, high_feb_tzm_tr_interpm, dim='init_year')
acc_low_feb_tzm = xr.corr(era5_feb_tzm_tr, low_feb_tzm_tr_interpm, dim='init_year')
acc_high_feb_2mon_tzm = xr.corr(era5_feb_tzm_tr_2mon, high_feb_tzm_tr_2mon, dim='init_year')
acc_low_feb_2mon_tzm = xr.corr(era5_feb_tzm_tr_2mon, low_feb_tzm_tr_2mon, dim='init_year')
acc_high_feb_2mon_tzm_jra = xr.corr(jra3q_feb_tzm_tr_2mon, high_feb_tzm_tr_2mon, dim='init_year')
acc_low_feb_2mon_tzm_jra = xr.corr(jra3q_feb_tzm_tr_2mon, low_feb_tzm_tr_2mon, dim='init_year')

# %% [markdown]
# ### Read in bootstrapped confidence intervals (calculated at ./DATA_SORT/SIGNIF/fig1/output_signif_fig1_timepre.py)

# %%
basepath_signif="/glade/campaign/cgd/cas/islas/python_savs/NCAR_CW3E_SMYLE/DATA_SORT/SIGNIF/fig1_2/"

signifdat_nov = xr.open_dataset(basepath_signif+"ci_pretime_initmon11_Tzm.nc")
signifdat_sep = xr.open_dataset(basepath_signif+"ci_pretime_initmon09_Tzm.nc")
signifdat_feb = xr.open_dataset(basepath_signif+"ci_pretime_initmon02_Tzm.nc")

# %% [markdown]
# ### Figure S2

# %%
fig = plt.figure(figsize=(16,16))

fsize=19

signifdat = xr.DataArray(np.ones([signifdat_nov.time.size,signifdat_nov.level.size]), 
                         coords=[signifdat_nov.time, signifdat_nov.level], dims=['time','level'])

signifdatplot = signifdat.where( ~((signifdat_nov.min95_low_cor > 0) | (signifdat_nov.max95_low_cor < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_nov_tzm), nan)
ax = qbo.plot_lev_time(fig, acc_low_nov_tzm, np.arange(0,acc_low_nov_tzm.time.size,1), acc_low_nov_tzm.level, 0.1,-1,1,'(a) ACC, T, L32, Nov',
                       0.02,0.47,0.73,0.97,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True, fsize=fsize)

signifdatplot = signifdat.where( ~((signifdat_nov.min95_high_cor > 0) | (signifdat_nov.max95_high_cor < 0)), nan)
ax = qbo.plot_lev_time(fig, acc_high_nov_tzm, np.arange(0,acc_high_nov_tzm.time.size,1), acc_high_nov_tzm.level, 0.1,-1,1,'(b) ACC, T, L83, Nov',
                       0.02,0.47,0.42,0.66,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True, fsize=fsize)

signifdatplot = signifdat.where( ~((signifdat_nov.min95_dif_cor > 0) | (signifdat_nov.max95_dif_cor < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_nov_tzm), nan)
ax = qbo.plot_lev_time(fig, acc_high_nov_tzm - acc_low_nov_tzm, np.arange(0,acc_high_nov_tzm.time.size,1), acc_high_nov_tzm.level, 0.1,-1,1,'(c) ACC, T, L83$-$L32, Nov',
                       0.02,0.47,0.11,0.35,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True, fsize=fsize)

ax = cbars.plotcolorbar(fig, 0.1,-1,1,'ACC',0.02,0.47,0.05,0.06,orient='horizontal',
                        ticks=[-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1], contourlines=True)

signifdatplot = signifdat.where( ~((signifdat_nov.min95_low_msss > 0) | (signifdat_nov.max95_low_msss < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_nov_tzm), nan)
ax = qbo.plot_lev_time(fig, msss_low_nov_tzm, np.arange(0,msss_low_nov_tzm.time.size,1), msss_low_nov_tzm.level,0.1,-1,1,'(d) MSSS, T, L32, Nov',
                       0.55,1.0,0.73,0.97,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True, fsize=fsize)

signifdatplot = signifdat.where( ~((signifdat_nov.min95_high_msss > 0) | (signifdat_nov.max95_high_msss < 0)), nan)
ax = qbo.plot_lev_time(fig, msss_high_nov_tzm, np.arange(0,msss_high_nov_tzm.time.size,1), msss_high_nov_tzm.level,0.1,-1,1,'(e) MSSS, T, L83, Nov',
                       0.55,1.0,0.42,0.66,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True, fsize=fsize)

signifdatplot = signifdat.where( ~((signifdat_nov.min95_dif_msss > 0) | (signifdat_nov.max95_dif_msss < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_nov_tzm), nan)
ax = qbo.plot_lev_time(fig, msss_high_nov_tzm - msss_low_nov_tzm, np.arange(0,msss_low_nov_tzm.time.size,1),msss_high_nov_tzm.level,0.1,-1,1,'(f) MSSS, T, L83$-$L32, Nov',
                       0.55,1.0,0.11,0.35,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True, fsize=fsize)

ax = cbars.plotcolorbar(fig, 0.1,-1,1,'MSSS',0.55,1.,0.05,0.06,orient='horizontal',
                        ticks=[-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1], contourlines=True)

fig.savefig(plotpath+'figS2.png', bbox_inches='tight', facecolor='white')
fig.savefig(plotpath+'figS2.pdf', bbox_inches='tight', facecolor='white')

# %%
fig = plt.figure(figsize=(16,16))

signifdat = xr.DataArray(np.ones([signifdat_sep.time.size,signifdat_sep.level.size]), 
                         coords=[signifdat_sep.time, signifdat_sep.level], dims=['time','level'])

signifdatplot = signifdat.where( ~((signifdat_sep.min95_low_cor > 0) | (signifdat_sep.max95_low_cor < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_sep_tzm), nan)
ax = qbo.plot_lev_time(fig, acc_low_sep_tzm, np.arange(0,acc_low_sep_tzm.time.size,1), acc_low_sep_tzm.level, 0.1,-1,1,'(a) ACC, L32, Sep, $[T]$',
                       0.02,0.32,0.8,0.97,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True)

signifdatplot = signifdat.where( ~((signifdat_sep.min95_high_cor > 0) | (signifdat_sep.max95_high_cor < 0)), nan)
ax = qbo.plot_lev_time(fig, acc_high_sep_tzm, np.arange(0,acc_high_sep_tzm.time.size,1), acc_high_sep_tzm.level, 0.1,-1,1,'(b) ACC, L83, Sep, $[T]$',
                       0.37,0.67,0.8,0.97,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True, ylabel=False)

signifdatplot = signifdat.where( ~((signifdat_sep.min95_dif_cor > 0) | (signifdat_sep.max95_dif_cor < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_sep_tzm), nan)
ax = qbo.plot_lev_time(fig, acc_high_sep_tzm - acc_low_sep_tzm, np.arange(0,acc_high_sep_tzm.time.size,1), acc_high_sep_tzm.level, 0.1,-1,1,'(c) ACC, L83$-$L32, Sep, $[T]$',
                       0.72,1.02,0.8,0.97,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True, ylabel=False)

ax = cbars.plotcolorbar(fig, 0.1,-1,1,'ACC',1.04,1.05,0.8,0.97,orient='vertical',
                        ticks=[-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1], contourlines=True)



signifdatplot = signifdat.where( ~((signifdat_sep.min95_low_msss > 0) | (signifdat_sep.max95_low_msss < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_sep_tzm), nan)
ax = qbo.plot_lev_time(fig, msss_low_sep_tzm, np.arange(0,msss_low_sep_tzm.time.size,1), msss_low_sep_tzm.level,0.1,-1,1,'(d) MSSS, L32, Sep, $[T]$',
                       0.02,0.32,0.57,0.74,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True)

signifdatplot = signifdat.where( ~((signifdat_sep.min95_high_msss > 0) | (signifdat_sep.max95_high_msss < 0)), nan)
ax = qbo.plot_lev_time(fig, msss_high_sep_tzm, np.arange(0,msss_high_sep_tzm.time.size,1), msss_high_sep_tzm.level,0.1,-1,1,'(e) MSSS, L83, Sep, $[T]$',
                       0.37,0.67,0.57,0.74,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True, ylabel=False)

signifdatplot = signifdat.where( ~((signifdat_sep.min95_dif_msss > 0) | (signifdat_sep.max95_dif_msss < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_sep_tzm), nan)
ax = qbo.plot_lev_time(fig, msss_high_sep_tzm - msss_low_sep_tzm, np.arange(0,msss_low_sep_tzm.time.size,1),msss_high_sep_tzm.level,0.1,-1,1,'(f) MSSS, L83$-$L32, Sep, $[T]$',
                       0.72,1.02,0.57,0.74,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True, ylabel=False)

ax = cbars.plotcolorbar(fig, 0.1,-1,1,'MSSS',1.04,1.05,0.57,0.74,orient='vertical',
                        ticks=[-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1], contourlines=True)



signifdat = xr.DataArray(np.ones([signifdat_feb.time.size,signifdat_feb.level.size]), 
                         coords=[signifdat_feb.time, signifdat_feb.level], dims=['time','level'])

signifdatplot = signifdat.where( ~((signifdat_feb.min95_low_cor > 0) | (signifdat_feb.max95_low_cor < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_feb_tzm), nan)
ax = qbo.plot_lev_time(fig, acc_low_feb_tzm, np.arange(0,acc_low_feb_tzm.time.size,1), acc_low_feb_tzm.level, 0.1,-1,1,'(g) ACC, L32, Feb, $[T]$',
                       0.02,0.32,0.3,0.47,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True)

signifdatplot = signifdat.where( ~((signifdat_feb.min95_high_cor > 0) | (signifdat_feb.max95_high_cor < 0)), nan)
ax = qbo.plot_lev_time(fig, acc_high_feb_tzm, np.arange(0,acc_high_feb_tzm.time.size,1), acc_high_feb_tzm.level, 0.1,-1,1,'(h) ACC, L83, Feb, $[T]$',
                       0.37,0.67,0.3,0.47,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True, ylabel=False)

signifdatplot = signifdat.where( ~((signifdat_feb.min95_dif_cor > 0) | (signifdat_feb.max95_dif_cor < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_feb_tzm), nan)
ax = qbo.plot_lev_time(fig, acc_high_feb_tzm - acc_low_feb_tzm, np.arange(0,acc_high_feb_tzm.time.size,1), acc_high_feb_tzm.level, 0.1,-1,1,'(i) ACC, L83$-$L32, Feb, $[T]$',
                       0.72,1.02,0.3,0.47,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True, ylabel=False)

ax = cbars.plotcolorbar(fig, 0.1,-1,1,'ACC',1.04,1.05,0.3,0.47,orient='vertical',
                        ticks=[-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1], contourlines=True)


signifdatplot = signifdat.where( ~((signifdat_feb.min95_low_msss > 0) | (signifdat_feb.max95_low_msss < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_feb_tzm), nan)
ax = qbo.plot_lev_time(fig, msss_low_feb_tzm, np.arange(0,msss_low_feb_tzm.time.size,1), msss_low_feb_tzm.level,0.1,-1,1,'(j) MSSS, L32, Feb, $[T]$',
                       0.02,0.32,0.07,0.24,plevvar='level', contourlines=True, contourlinescale=1, signifdat = signifdatplot, stipplesignif=True)

signifdatplot = signifdat.where( ~((signifdat_feb.min95_high_msss > 0) | (signifdat_feb.max95_high_msss < 0)), nan)
ax = qbo.plot_lev_time(fig, msss_high_feb_tzm, np.arange(0,msss_high_feb_tzm.time.size,1), msss_high_feb_tzm.level,0.1,-1,1,'(k) MSSS, L83, Feb, $[T]$',
                       0.37,0.67,0.07,0.24,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True, ylabel=False)

signifdatplot = signifdat.where( ~((signifdat_feb.min95_dif_msss > 0) | (signifdat_feb.max95_dif_msss < 0)), nan)
signifdatplot = signifdatplot.where(~np.isnan(acc_low_feb_tzm), nan)
ax = qbo.plot_lev_time(fig, msss_high_feb_tzm - msss_low_feb_tzm, np.arange(0,msss_low_feb_tzm.time.size,1),msss_high_feb_tzm.level,0.1,-1,1,'(l) MSSS, L83$-$L32, Feb, $[T]$',
                       0.72,1.02,0.07,0.24,plevvar='level', contourlines=True, contourlinescale=1, signifdat=signifdatplot, stipplesignif=True, ylabel=False)

ax = cbars.plotcolorbar(fig, 0.1,-1,1,'MSSS',1.04,1.05,0.07,0.24,orient='vertical',
                        ticks=[-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1], contourlines=True)

fig.savefig(plotpath+'figS3.png', bbox_inches='tight', facecolor='white')
fig.savefig(plotpath+'figS3.pdf', bbox_inches='tight', facecolor='white')
